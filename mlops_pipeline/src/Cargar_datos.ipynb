# %% [markdown]
# # Cargar_datos.ipynb
#
# **Módulo:** Ingesta de datos
#
# **Propósito:** Carga inicial y lectura del dataset `Base_de_datos.xlsx`.
#
# **Funcionalidades previstas (a desarrollar en V1.0.1):**
# - Lectura del archivo Excel con pandas
# - Inspección inicial: shape, dtypes, primeras filas
# - Conteo de nulos y duplicados
# - Verificación de integridad básica del dataset
#
# **Autor:** Cristian García
#
# **Fecha de creación:** 2026-05-26
#
# **Versión:** V1.0.0 (placeholder - sin implementación)
